# %%
import pandas as pd

# %%
df = pd.read_csv('../results/pipeline/3295992--2e-05-cosine.csv')

# %%
df[df['label'] == 'spurious']
# Out:
#      Unnamed: 0  modality polarity genericity    trigger  \
# 17            0  Asserted  UNKNOWN    UNKNOWN       head
# 18            1  Asserted  UNKNOWN    UNKNOWN       shot
# 19            2  Asserted  UNKNOWN    UNKNOWN       push
# 20            3  Asserted  UNKNOWN    UNKNOWN     combat
# 21            4  Asserted  UNKNOWN    UNKNOWN       dead
# ..          ...       ...      ...        ...        ...
# 957         940  Asserted  UNKNOWN    UNKNOWN    assault
# 958         941  Asserted  UNKNOWN    UNKNOWN       shot
# 959         942  Asserted  UNKNOWN    UNKNOWN  Torturing
# 960         943  Asserted  UNKNOWN    UNKNOWN     killed
# 961         944  Asserted  UNKNOWN    UNKNOWN        die
#
#                                                   text     type     label  \
# 17   It was in northern Iraq today that an eight ar...  UNKNOWN  spurious
# 18   A day ago it was controlled by Iraqi troops an...  UNKNOWN  spurious
# ...

# %%
df[df['label'] == 'discovered']
# Out:
#     Unnamed: 0  modality  polarity genericity   trigger  \
# 0            0  Asserted  Positive   Specific    killed
# 1            1  Asserted  Positive   Specific       war
# 2            2     Other  Positive   Specific       war
# 3            3     Other  Positive    Generic       war
# 4            4     Other  Positive    Generic       war
# 5            5  Asserted  Positive   Specific    attack
# 6            6  Asserted  Positive   Specific   injured
# 7            7  Asserted  Positive   Specific       war
# 8            8  Asserted  Positive   Specific       war
# 9            9  Asserted  Positive   Specific  fighting
# 10          10  Asserted  Positive   Specific      died
# 11          11  Asserted  Positive   Specific       war
# 12          12  Asserted  Positive    Generic       war
# 13          13     Other  Positive    Generic       war
# 14          14  Asserted  Positive   Specific    attack
# 15          15     Other  Positive    Generic    attack
# ...

# %%
df[df['label'] == 'undiscovered'][['trigger', 'text']]
# Out:
#       Unnamed: 0  modality  polarity genericity   trigger  \
# 962            0  Asserted  Positive   Specific       hit
# 963            1  Asserted  Positive   Specific     drive
# 964            2  Asserted  Positive   Specific  pummeled
# 965            3  Asserted  Positive   Specific   retreat
# 966            4  Asserted  Positive   Specific        go
# ...          ...       ...       ...        ...       ...
# 1854         892     Other  Positive    Generic       war
# 1855         893     Other  Positive    Generic       war
# 1856         894     Other  Positive    Generic       war
# 1857         895  Asserted  Positive   Specific     speak
# 1858         896     Other  Positive    Generic       war
#
#                                                    text       type  \
# 962   It was in northern Iraq today that an eight ar...     Attack
# 963   A day ago it was controlled by Iraqi troops an...  Transport
# ...
